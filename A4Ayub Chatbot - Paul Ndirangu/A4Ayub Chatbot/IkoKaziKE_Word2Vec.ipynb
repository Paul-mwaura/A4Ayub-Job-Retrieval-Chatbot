# %% [markdown]
# # <span style="color:#800000"> Fitting a Word2Vec Model on the IkoKaziKE data</span>

# %% [markdown]
# <span style="color:orange">Here,I call in the data,check for missing values,keep what I need and use the BOW model </span>

# %%
#Import the necessary libraries
# !pip install gensim
import re
import string 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import graph_objs as go
import nltk
import warnings
warnings.filterwarnings("ignore")
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from collections import Counter
from bs4 import BeautifulSoup
# Out:
# Collecting gensim
#   Downloading gensim-3.8.3-cp37-cp37m-win_amd64.whl (24.2 MB)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\eunice mutahi\anaconda3\lib\site-packages (from gensim) (1.4.1)
# Requirement already satisfied: six>=1.5.0 in c:\users\eunice mutahi\anaconda3\lib\site-packages (from gensim) (1.14.0)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\eunice mutahi\anaconda3\lib\site-packages (from gensim) (1.18.1)
# Collecting Cython==0.29.14
#   Downloading Cython-0.29.14-cp37-cp37m-win_amd64.whl (1.7 MB)
# Collecting smart-open>=1.8.1
#   Downloading smart_open-2.1.0.tar.gz (116 kB)
# Requirement already satisfied: requests in c:\users\eunice mutahi\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.22.0)
# Requirement already satisfied: boto in c:\users\eunice mutahi\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.49.0)
# Collecting boto3
#   Downloading boto3-1.14.48.tar.gz (97 kB)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\eunice mutahi\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\eunice mutahi\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\eunice mutahi\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\eunice mutahi\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (1.25.8)
# Collecting botocore<1.18.0,>=1.17.48
#   Downloading botocore-1.17.48-py2.py3-none-any.whl (6.5 MB)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading s3transfer-0.3.3-py2.py3-none-any.whl (69 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\eunice mutahi\anaconda3\lib\site-packages (from botocore<1.18.0,>=1.17.48->boto3->smart-open>=1.8.1->gensim) (2.8.1)
# Collecting docutils<0.16,>=0.10
#   Downloading docutils-0.15.2-py3-none-any.whl (547 kB)
# Building wheels for collected packages: smart-open, boto3
#   Building wheel for smart-open (setup.py): started
#   Building wheel for smart-open (setup.py): finished with status 'done'
#   Created wheel for smart-open: filename=smart_open-2.1.0-py3-none-any.whl size=110324 sha256=5234c37aa9188172e422b92ede9ae6338510fa1a54e1da12b09eef4c6c951557
#   Stored in directory: c:\users\eunice mutahi\appdata\local\pip\cache\wheels\56\b5\6d\86dbe4f29d4688e5163a8b8c6b740494310040286fca4dc648
#   Building wheel for boto3 (setup.py): started
#   Building wheel for boto3 (setup.py): finished with status 'done'
#   Created wheel for boto3: filename=boto3-1.14.48-py2.py3-none-any.whl size=127855 sha256=9dd0735141e55e2b5f022c72279929b08eefc43dd838fd47fa90d646f13de80b
#   Stored in directory: c:\users\eunice mutahi\appdata\local\pip\cache\wheels\b0\f8\d9\d2a816eb3b5fed353cf3e7746d2c3bd0cac694045d063a2b53
# Successfully built smart-open boto3
# Installing collected packages: Cython, jmespath, docutils, botocore, s3transfer, boto3, smart-open, gensim
#   Attempting uninstall: Cython
#     Found existing installation: Cython 0.29.15
#     Uninstalling Cython-0.29.15:
#       Successfully uninstalled Cython-0.29.15
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.16
#     Uninstalling docutils-0.16:
#       Successfully uninstalled docutils-0.16
# Successfully installed Cython-0.29.14 boto3-1.14.48 botocore-1.17.48 docutils-0.15.2 gensim-3.8.3 jmespath-0.10.0 s3transfer-0.3.3 smart-open-2.1.0

# %%
#import the dataset
df_tweet=pd.read_csv("twitter-job-hunter-chatbot.csv")
df_tweet.head()
# Out:
#            Datetime                                               Text  \
# 0  18/07/2020 11:46  b"Ladies!!! #IkoKaziKE #IkoKazi Today, I reall...
# 1  18/07/2020 11:18  b'#IkoKaziKe #IkoKazi Looking for a Audit Trai...
# 2  18/07/2020 09:08  b'@moneychapKE are an online crowdfunding and ...
# 3  18/07/2020 09:07  b'We are an online crowdfunding and fundraisin...
# 4  18/07/2020 08:46  b'Striding into the weekend with a productive ...
#
#                Source                                          harsh tag  \
# 0      b'Mimimkenya7'                           ['IkoKaziKE', 'IkoKazi']
# 1  b'MtandaoPromoter'                           ['IkoKaziKe', 'IkoKazi']
# 2   b'KameneAndJalas'  ['KameneAndJalas', 'ikoJob', 'TwendeKaziKe', '...
# 3      b'moneychapKE'                           ['IkoKazi', 'IkoKaziKE']
# 4         b'amunsoft'  ['webdeveloper', 'business', 'IkoKazi', 'IkoKa...
#
#    Favourite Count  Retweets   6   7 submitter_name
# 0              NaN     775.0 NaN NaN    Brian Cheye
# 1              NaN       5.0 NaN NaN    Brian Cheye
# 2              NaN   15675.0 NaN NaN    Brian Cheye
# 3              NaN      79.0 NaN NaN    Brian Cheye
# 4              NaN       2.0 NaN NaN    Brian Cheye

# %%
print(df_tweet.shape)
# Out:
# (29674, 9)

# %%
#df_tweet.info()

# %%
#Variable Data types
df_tweet.dtypes
# Out:
# Datetime            object
# Text                object
# Source              object
# harsh tag           object
# Favourite Count    float64
# Retweets           float64
# 6                  float64
# 7                  float64
# submitter_name      object
# dtype: object

# %% [markdown]
# # Cleaning the Data

# %%
df_tweet.isnull().sum()
# Out:
# Datetime               0
# Text                   0
# Source               214
# harsh tag          24953
# Favourite Count      532
# Retweets            2552
# 6                   6599
# 7                   6599
# submitter_name         0
# dtype: int64

# %% [markdown]
# Since harsh tag has very many missing values that will be unreasonable to drop,
# We fill the missing values with "no tag" the drop the rest of the na's

# %%
df_tweet["harsh tag"].fillna("no tag",inplace=True)

# %% [markdown]
# <span style="color:green">We can now drop the na values without worrying of dropping so many observations </span>

# %%
df_tweet.dropna(inplace=True)

# %%
#confirm in there are still na values
df_tweet.isnull().sum()
# Out:
# Datetime           0
# Text               0
# Source             0
# harsh tag          0
# Favourite Count    0
# Retweets           0
# 6                  0
# 7                  0
# submitter_name     0
# dtype: int64

# %%
df_tweet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22865 entries, 4047 to 27121
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Datetime         22865 non-null  object
#  1   Text             22865 non-null  object
#  2   Source           22865 non-null  object
#  3   harsh tag        22865 non-null  object
#  4   Favourite Count  22865 non-null  float64
#  5   Retweets         22865 non-null  float64
#  6   6                22865 non-null  float64
#  7   7                22865 non-null  float64
#  8   submitter_name   22865 non-null  object
# dtypes: float64(4), object(5)
# memory usage: 1.7+ MB

# %%
#check if we have any dulicates
print(df_tweet.duplicated().any())
# Out:
# True

# %%
#drop the duplicates
df_tweet.drop_duplicates(keep=False,inplace=True)

# %%
#Confirm if the duplicates have been dropped
print(df_tweet.duplicated().any())
# Out:
# False

# %%
df_tweet.describe()
# Out:
#        Favourite Count      Retweets             6             7
# count     2.280700e+04  22807.000000  2.280700e+04  22807.000000
# mean      3.824571e+02      5.172535  3.560263e+02    147.239225
# std       1.031095e+04     82.011641  1.030685e+04   1213.919912
# min       0.000000e+00      0.000000  0.000000e+00      0.000000
# 25%       0.000000e+00      0.000000  0.000000e+00      0.000000
# 50%       1.000000e+00      0.000000  0.000000e+00      0.000000
# 75%       2.000000e+00      2.000000  0.000000e+00      0.000000
# max       1.496504e+06   4167.000000  1.496395e+06  28407.000000

# %% [markdown]
# # <u><span style="color:orange"> Dealing with outliers </span></u>

# %%
from scipy import stats
num = ['Retweets']

for i, col in enumerate(num):
    z=np.abs(stats.zscore(df_tweet[col]))
print(z)
# Out:
# [0.06307212 0.06307212 0.05087846 ... 0.05087846 0.05087846 0.06307212]

# %%
#subset the data with observations whose z score is less than 3
df1=df_tweet[(z<3)]
print (f"Data frame with outliers had : {(df_tweet.shape[0])}")
print(f"Data frame without outliers has : {df1.shape[0]}")
# Out:
# Data frame with outliers had : 22807
# Data frame without outliers has : 22768

# %%
#remove spaces and convert the variable names to lower
df1.columns=df1.columns.str.lower().str.strip()

# %%
#Cleaning text,lower remove punctuation,white space
#create a function then use it to clean the column texts
'''Make text lowercase, remove text in square brackets,remove links,remove punctuation
    and remove words containing numbers.'''
def clean_text(text):
    text=str(text).lower()
    text=re.sub('\[.*?\]','',text)   # question marks,square brackets
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    
    text = re.sub("\'s", " ", text) # we have cases like "Sam is" or "Sam's" (i.e. his) these two cases aren't separable, I choose to compromise are kill "'s" directly
    text = re.sub(" whats ", " what is ", text, flags=re.IGNORECASE)
    text = re.sub("\'ve", " have ", text)
    text = re.sub("can't", "can not", text)
    text = re.sub("n't", " not ", text)
    text = re.sub("i'm", "i am", text, flags=re.IGNORECASE)
    text = re.sub("\'re", " are ", text)
    text = re.sub("\'d", " would ", text)
    text = re.sub("\'ll", " will ", text)
    text = re.sub("e\.g\.", " eg ", text, flags=re.IGNORECASE)
    text = re.sub("(\d+)(kK)", " \g<1>000 ", text)
    text = re.sub("e-mail", " email ", text, flags=re.IGNORECASE)
    text = re.sub("\(s\)", " ", text, flags=re.IGNORECASE)
    text = re.sub("[c-fC-F]\:\/", " disk ", text)
    return text

# %%
df1['text']= df1['text'].apply(lambda x:clean_text(x))
df1['source']=df1['source'].apply(lambda x:clean_text(x))

# %%
df1.head()
# Out:
#                        datetime  \
# 4047  2020-07-18 10:16:18+00:00
# 4048  2020-07-18 10:09:08+00:00
# 4049  2020-07-18 10:05:52+00:00
# 4050  2020-07-18 10:05:22+00:00
# 4051  2020-07-18 10:05:16+00:00
#
#                                                    text        source  \
# 4047  job seekers  free cover letter template   ikok...   simoningari
# 4048  get the latest and best car shade and all cust...    simonmagak
# 4049  join jobalertke for latest updates on     ikok...   simoningari
# 4050  hey people im looking for a farm manager with ...  vidolebaridi
# 4051  job hunting can be emotionally draining  to en...   simoningari
#
#      harsh tag  favourite count  retweets       6       7  submitter_name
# 4047    no tag              1.0       0.0  4342.0  4994.0  Dennis Mwaniki
# 4048    no tag              0.0       0.0    28.0    92.0  Dennis Mwaniki
# 4049    no tag              2.0       1.0  4342.0  4994.0  Dennis Mwaniki
# 4050    no tag              0.0       0.0   141.0   485.0  Dennis Mwaniki
# 4051    no tag              0.0       0.0  4342.0  4994.0  Dennis Mwaniki

# %%
#use a subset of what I need.
df_w2v = df1[["datetime" ,"text","source","harsh tag","retweets"]]  #get rid of 6,7 and submitter_name

# %%
df_w2v.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22768 entries, 4047 to 27121
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   datetime   22768 non-null  object
#  1   text       22768 non-null  object
#  2   source     22768 non-null  object
#  3   harsh tag  22768 non-null  object
#  4   retweets   22768 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 1.0+ MB

# %%
df_w2v.dtypes
# Out:
# datetime      object
# text          object
# source        object
# harsh tag     object
# retweets     float64
# dtype: object

# %% [markdown]
# # <span style="color:maroon">Word2Vec Model </span>

# %% [markdown]
# Here we will implement the Word2vec model using the Gensim library
# Procedure
# <br> 0.Create/Identify your corpus </br>
# <br> 1.Tokenize </br>   //preprocessing
# <br> 2.Remove Stopwords</br>
# <br> 4.Modelling with BOW
# <br> 0. Split Test and Train Data <br>

# %%
#1.Tokenizing

nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Eunice
# [nltk_data]     Mutahi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Eunice
# [nltk_data]     Mutahi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Creating the model

# %%
def prep_text(text) :

     # 1. Remove HTML.
    my_text = BeautifulSoup(text,"html.parser").get_text()
    
    #Tokenize words
    tokens=nltk.word_tokenize(my_text)
    
    #Define stopwords
    stops=set(stopwords.words("english"))
    # Convert the stopwords list to "set" data type.
    #stops = set(nltk.corpus.stopwords.words("english"))
    
    #Remove the stopwords
    words=[x for x in tokens if  not x in stops]
   
    
    #Remove the stopwords
    #for i in range(0,len(words)):
       # words[i]=[x for x in words if  not x in stops]
    
    return words

# %%
#Performing the iterative preps on each of the statements
df_w2v['preped_text']=df_w2v['text'].apply(prep_text)

# %%
df_w2v.head(10)
# Out:
#                        datetime  \
# 4047  2020-07-18 10:16:18+00:00
# 4048  2020-07-18 10:09:08+00:00
# 4049  2020-07-18 10:05:52+00:00
# 4050  2020-07-18 10:05:22+00:00
# 4051  2020-07-18 10:05:16+00:00
# 4052  2020-07-18 09:59:06+00:00
# 4053  2020-07-18 09:47:12+00:00
# 4054  2020-07-18 09:46:00+00:00
# 4055  2020-07-18 09:40:05+00:00
# 4056  2020-07-18 09:39:26+00:00
#
#                                                    text           source  \
# 4047  job seekers  free cover letter template   ikok...      simoningari
# 4048  get the latest and best car shade and all cust...       simonmagak
# 4049  join jobalertke for latest updates on     ikok...      simoningari
# 4050  hey people im looking for a farm manager with ...     vidolebaridi
# 4051  job hunting can be emotionally draining  to en...      simoningari
# 4052             job whatsapp groups to join  ikokazike      simoningari
# 4053  i am looking for good carpenter to do some wor...        babananii
# 4054  kot were still taking applications for regiona...         qsskenya
# 4055   the east african community is looking for a h...    findjobskenya
# 4056  vacancy at miritini medical labtech qualificat...  hossanamiritini
#
#      harsh tag  retweets                                        preped_text
# 4047    no tag       0.0  [job, seekers, free, cover, letter, template, ...
# 4048    no tag       0.0  [get, latest, best, car, shade, customised, ca...
# 4049    no tag       1.0  [join, jobalertke, latest, updates, ikokazike,...
# 4050    no tag       0.0  [hey, people, im, looking, farm, manager, spec...
# 4051    no tag       0.0  [job, hunting, emotionally, draining, ensure, ...
# 4052    no tag       0.0           [job, whatsapp, groups, join, ikokazike]
# 4053    no tag       1.0  [looking, good, carpenter, work, recommendatio...
# 4054    no tag       1.0  [kot, still, taking, applications, regional, h...
# 4055    no tag       0.0  [east, african, community, looking, human, res...
# 4056    no tag       3.0  [vacancy, miritini, medical, labtech, qualific...

# %%
from gensim.models import Word2Vec

# %%
word2vec=Word2Vec(df_w2v['preped_text'],min_count=2)      # Specifies to include only words in the model that appear atleast 10 times in the corpus

# %%
#Lets view the vocabulary
vocabulary=word2vec.wv.vocab
print(vocabulary)
# Out:
# {'job': <gensim.models.keyedvectors.Vocab object at 0x000001CA20E5F748>, 'seekers': <gensim.models.keyedvectors.Vocab object at 0x000001CA241E6788>, 'free': <gensim.models.keyedvectors.Vocab object at 0x000001CA241E6308>, 'cover': <gensim.models.keyedvectors.Vocab object at 0x000001CA21070408>, 'letter': <gensim.models.keyedvectors.Vocab object at 0x000001CA2106A808>, 'template': <gensim.models.keyedvectors.Vocab object at 0x000001CA2106A788>, 'ikokazike': <gensim.models.keyedvectors.Vocab object at 0x000001CA2106A4C8>, 'patakazike': <gensim.models.keyedvectors.Vocab object at 0x000001CA2106AE88>, 'gethired': <gensim.models.keyedvectors.Vocab object at 0x000001CA2106A688>, 'jobseeker': <gensim.models.keyedvectors.Vocab object at 0x000001CA2106A6C8>, 'get': <gensim.models.keyedvectors.Vocab object at 0x000001CA2106A308>, 'latest': <gensim.models.keyedvectors.Vocab object at 0x000001CA2106A488>, 'best': <gensim.models.keyedvectors.Vocab object at 0x000001CA2106AC88>, 'car': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432388>, 'shade': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432608>, 'customised': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432C48>, 'canopies': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432B88>, 'pollycarbonate': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432B48>, 'shades': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432EC8>, 'cabro': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432088>, 'affordable': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432448>, 'prices': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432D48>, 'call': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432048>, 'us': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432408>, 'president': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432A08>, 'kenyatta': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432188>, 'atwoli': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432588>, 'mpesa': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432948>, 'babuowino': <gensim.models.keyedvectors.Vocab object at 0x000001CA244325C8>, 'join': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432808>, 'jobalertke': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432148>, 'updates': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432A48>, 'jobseekers': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432748>, 'jobs': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432908>, 'internships': <gensim.models.keyedvectors.Vocab object at 0x000001CA24432988>, 'recruitment': <gensim.models.keyedvectors.Vocab object at 0x000001CA2442E9C8>, 'talent': <gensim.models.keyedvectors.Vocab object at 0x000001CA2442E488>, 'recruiters': <gensim.models.keyedvectors.Vocab object at 0x000001CA2442EC08>, 'interns': <gensim.models.keyedvectors.Vocab object at 0x000001CA2442E348>, 'scholarships': <gensim.models.keyedvectors.Vocab object at 0x000001CA2442EEC8>, 'jobalert': <gensim.models.keyedvectors.Vocab object at 0x000001CA2442E088>, 'hr': <gensim.models.keyedvectors.Vocab object at 0x000001CA2442E988>, 'hiring': <gensim.models.keyedvectors.Vocab object at 0x000001CA2442E448>, 'hey': <gensim.models.keyedvectors.Vocab object at 0x000001CA2442E308>, 'people': <gensim.models.keyedvectors.Vocab object at 0x000001CA2442EA48>, 'im': <gensim.models.keyedvectors.Vocab object at 0x000001CA2442ED48>, 'looking': <gensim.models.keyedvectors.Vocab object at 0x000001CA2442E548>, 'farm': <gensim.models.keyedvectors.Vocab object at 0x000001CA2442E248>, 'manager': <gensim.models.keyedvectors.Vocab object at 0x000001CA2442EF48>, 'specialisation': <gensim.models.keyedvectors.Vocab object at 0x000001CA2442E948>, 'animal': <gensim.models.keyedvectors.Vocab object at 0x000001CA2442ECC8>, 'husbandry': <gensim.models.keyedvectors.Vocab object at 0x000001CA2442E0C8>, 'addition': <gensim.models.keyedvectors.Vocab object  ...

# %%
# preping text for BOW :remove stopwords and lemmatize

def counting(text) :
    my_text = BeautifulSoup(text,"html.parser").get_text()
    
    #Tokenize words
    tokens=nltk.word_tokenize(my_text)
    
    #Define stopwords
    stops=set(stopwords.words("english"))
    
    
    #Remove the stopwords
    words=[x for x in tokens if  not x in stops]
    #Confirming with the frequencies
    wordscount={}
    
    for data in my_text:
        for word in words:
            if word not in wordscount.keys():
                wordscount[word]= 1
            else:
                wordscount[word] += 1
    #print(wordscount)
    
    return wordscount

# %%
#Performing the iterative preps on each of the statements
df_w2v['count_text']=df_w2v['text'].apply(counting)

# %%
print(df_w2v['count_text'])
# Out:
# 4047     {'job': 81, 'seekers': 81, 'free': 81, 'cover'...
# 4048     {'get': 178, 'latest': 178, 'best': 178, 'car'...
# 4049     {'join': 173, 'jobalertke': 173, 'latest': 173...
# 4050     {'hey': 165, 'people': 165, 'im': 165, 'lookin...
# 4051     {'job': 528, 'hunting': 352, 'emotionally': 17...
#                                ...
# 27116    {'looking': 115, 'job': 115, 'opportunities': ...
# 27117    {'looking': 116, 'job': 116, 'opportunities': ...
# 27118    {'looking': 115, 'job': 115, 'opportunities': ...
# 27119    {'looking': 98, 'job': 98, 'opportunities': 98...
# 27121    {'used': 30, 'original': 30, 'padsikokazike': 30}
# Name: count_text, Length: 22768, dtype: object

# %% [markdown]
# # Model Analysis

# %% [markdown]
# Lets now explore what we created
#
# Finding Vectors for a Word
# We know that the Word2Vec model converts words to their corresponding vectors. Let's see how we can view vector representation of any particular word.

# %%
vec1=word2vec.wv['jobs']
print(vec1)
# Out:
# [ 5.40504038e-01  9.66072679e-01  9.84730124e-01  9.83429015e-01
#  -7.59980381e-01  6.62668943e-01  5.87260962e-01  2.64047056e-01
#  -5.49408235e-02  3.82870138e-02  3.75827610e-01 -9.79443714e-02
#   1.53482902e+00  2.80314296e-01 -8.94509777e-02 -5.48211694e-01
#  -2.57424384e-01  8.87459040e-01  1.03759892e-01  1.04219377e+00
#   7.11032867e-01  2.20856738e+00  1.68405843e+00  9.24764201e-02
#   8.11248004e-01  1.08494103e+00 -6.92745205e-03  5.36264718e-01
#  -7.67842889e-01 -7.40501344e-01  1.16757369e+00 -4.18461561e-01
#   3.79425108e-01 -3.14091504e-01  2.59481072e-01 -4.78525579e-01
#   1.97310090e-01 -1.37005734e+00  6.91328764e-01 -7.16852784e-01
#   6.13990784e-01 -1.16432154e+00  7.37183571e-01  3.88904437e-02
#   1.07252026e+00 -1.00167476e-01  1.58698082e-01  2.01555419e+00
#   2.52359182e-01  3.73059750e-01  1.85973632e+00  3.34861815e-01
#  -7.77836800e-01  1.20185447e+00  1.39400281e-03 -6.08495414e-01
#  -6.80903912e-01  3.49670887e-01 -2.65605241e-01  9.40679431e-01
#   1.95879757e+00  3.53820533e-01 -8.95091474e-01 -4.05117571e-02
#   2.16655672e-01  1.17921460e+00 -1.14742279e+00 -1.32028449e+00
#   9.26873207e-01 -7.62210310e-01  4.00490999e-01  7.87776232e-01
#   4.54784483e-01  3.51848781e-01 -9.63909984e-01  9.83009815e-01
#   8.85578275e-01 -2.17917466e+00  4.17269856e-01 -8.16707313e-02
#  -1.66651320e+00 -6.81556642e-01 -1.31043708e-02  1.89710605e+00
#  -5.05921721e-01  7.55463004e-01 -9.82251048e-01  1.32912707e+00
#  -1.65536076e-01 -1.38776422e+00  1.45748243e-01 -7.48908937e-01
#   3.04907829e-01 -1.55433416e+00 -5.82585037e-01 -1.58513617e-02
#  -4.78984892e-01 -3.74348372e-01  4.21646118e-01 -2.46700719e-02]

# %% [markdown]
# Finding Similar Words
#
# Earlier we said that contextual information of the words is not lost using Word2Vec approach. We can verify this by finding all the words similar to the word "seeking".

# %%
similar=word2vec.wv.most_similar('job')
print(similar)
# Out:
# [('tenementmanager', 0.8382851481437683), ('tforce', 0.8358317613601685), ('idev', 0.8339505195617676), ('rackspace', 0.833041787147522), ('angularjs', 0.8311528563499451), ('teller', 0.8306150436401367), ('kcb', 0.8305569887161255), ('smarsh', 0.8271684646606445), ('bss', 0.8233267068862915), ('registered', 0.8212844133377075)]
